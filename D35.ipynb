# %% [markdown]
# ## 作業:
# 某工廠想知道兩條不同的生產線的產品不良率是否有所不同，由兩條生產線中各抽取 300 個樣本，第一組有  75 個不良品，第二組有 30 個不良品，我們可以宣稱生產線所生產出的產品不良率不相同? (以 0.05 為顯著水準)?
# (提示:透過課程投影片的步驟，需思考 𝐻_0、 𝐻_1 的寫法和範例不同唷。)

# %%
# library
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import math
import statistics
import seaborn as sns
import statsmodels.stats.proportion

# %%
A=[75,30] #兩條生產線各自的不良品數目
B=[300,300]#兩條生產線各自抽取的 300 個樣本
answer=statsmodels.stats.proportion.proportions_ztest(A, B, alternative='two-sided')
print('Z-test(檢定量):',answer[0])
print('P-value值:',answer[1])
# Out:
# Z-test(檢定量): 4.834937784152282
# P-value值: 1.3318728439003627e-06

# %% [markdown]
# 因為P-value值>0.05，因次𝐻_0被拒絕，而𝐻_1通過，所以我們可以宣稱兩條生產線所生產出的產品不良率不相同。
